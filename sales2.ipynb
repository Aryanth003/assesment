# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanth003/assesment/blob/main/sales2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Day_7_sales_data.csv')

# %%
df.head()
# Out:
#          Date Product Region    Sales  Profit  Quantity  Profit Margin
# 0  2023-01-02  Tablet   East  1061.81  236.12         7      22.237500
# 1  2023-01-06  Laptop  North  1926.07  246.34         8      12.789774
# 2  2023-01-03  Tablet   East  1597.99  253.17         3      15.843028
# 3  2023-01-20  Tablet  North  1397.99  242.23         1      17.327020
# 4  2023-01-04  Laptop   West   734.03  140.36         4      19.121834

# %%
df[df['Sales']>1000]
# Out:
#           Date     Product Region    Sales  Profit  Quantity  Profit Margin
# 0   2023-01-02      Tablet   East  1061.81  236.12         7      22.237500
# 1   2023-01-06      Laptop  North  1926.07  246.34         8      12.789774
# 2   2023-01-03      Tablet   East  1597.99  253.17         3      15.843028
# 3   2023-01-20      Tablet  North  1397.99  242.23         1      17.327020
# 7   2023-01-07  Smartphone   East  1799.26  364.97         4      20.284450
# 8   2023-01-11  Smartphone   West  1401.67  306.24         2      21.848224
# 9   2023-01-01      Laptop  North  1562.11  170.72         6      10.928808
# 11  2023-01-12      Laptop   West  1954.86  262.16         4      13.410679
# 12  2023-01-09     Monitor  North  1748.66  197.62         6      11.301225
# 17  2023-01-18     Monitor   West  1287.13  153.86         7      11.953727
# 18  2023-01-13      Tablet   West  1147.92  271.88         9      23.684577

# %%
df[df['Region'] == 'East']
# Out:
#           Date     Product Region    Sales  Profit  Quantity  Profit Margin
# 0   2023-01-02      Tablet   East  1061.81  236.12         7      22.237500
# 2   2023-01-03      Tablet   East  1597.99  253.17         3      15.843028
# 6   2023-01-14    Keyboard   East   587.13   82.16         8      13.993494
# 7   2023-01-07  Smartphone   East  1799.26  364.97         4      20.284450
# 14  2023-01-08      Laptop   East   772.74  226.51         2      29.312576

# %%
df[df['Sales']>1000]
df[df['Region'] == 'East']
df['Profit_Per_Unit'] = df['Profit'] / df['Quantity']
print(df.head())

# %%
df['High_Sales'] = ['Yes' if x > 1000 else 'No' for x in df['Sales']]
print(df.head())
