# %%
print("Hello world")
# Out:
# Hello world

# %%
"arya".count("a")
# Out:
# 2

# %%
var=19

# %%
f"Malla reddy university   {var}       "
# Out:
# 'Malla reddy university   19       '

# %%
s=" hello ?? world ??19"
s.split()
# Out:
# ['hello', '??', 'world', '??19']
